# %%
import matplotlib.pyplot as plt
import numpy as np
plt.xticks(np.arange(0,51,5))
plt.yticks(np.arange(0,11,1))
plt.title("First Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
plt.plot([1,2,3,4],[1,4,9,16],marker='o')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.title("y = x^2")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
x = np.arange(0,11,2)
y = np.arange(0,11,2)

plt.plot(x,x**2,'o')
plt.plot(x,x**2,)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.title("Default X axis")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

y = np.array([3,6,9,12,15,18,21,27,30])
plt.plot(y,marker = 'D')

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Gender_data.csv')

plt.xlabel('Weight')
plt.ylabel('Height')

x = df.drop('Height',axis=1)
y = df['Height']
plt.xticks(np.arange(40,100,10))
plt.yticks(np.arange(130,210,10))
#plt.plot(x,y,marker = 'o')
plt.plot(x,y,"g^")

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.arange(1,5)
b = a**3

plt.title("a=b^3")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.plot(a,b,marker="o")

# %%
plt.plot(a,b,"go")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("green color marking")
# Out:
# Text(0.5, 1.0, 'green color marking')

# %%
'''
1)plot the simple line chart of following data x = [1, 5, 8, 9, 7, 11, 8, 12, 14, 9, 5] y = [3, 7, 9, 6, 4, 5,
14, 7, 6, 16, 12]
'''

import matplotlib.pyplot as plt

x = [1, 5, 8, 9, 7, 11, 8, 12, 14, 9, 5]
y = [3, 7, 9, 6, 4, 5, 14, 7, 6, 16, 12]

font1 = {'family':'serif','color':'blue','size':15}

plt.xlabel("X-axis",fontdict = font1)
plt.ylabel("Y-axis",fontdict = font1)

plt.plot(x,y,marker="o")
plt.grid()
plt.show()
