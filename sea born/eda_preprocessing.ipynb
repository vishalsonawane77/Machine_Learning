# %%
import pandas as pd

df = pd.read_csv("titanic_data.csv")
df.drop(["PassengerId","Name","Fare","Cabin"],axis=1).isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Embarked      2
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].median())       #median for numerical values
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode)   #mode for categorical values
df.drop(["PassengerId","Name","Fare","Cabin"],axis=1).isnull().sum()
df.drop(["PassengerId","Name","Fare","Cabin"],axis=1)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket Embarked
# 0           0       3    male  22.0      1      0         A/5 21171        S
# 1           1       1  female  38.0      1      0          PC 17599        C
# 2           1       3  female  26.0      0      0  STON/O2. 3101282        S
# 3           1       1  female  35.0      1      0            113803        S
# 4           0       3    male  35.0      0      0            373450        S
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 886         0       2    male  27.0      0      0            211536        S
# 887         1       1  female  19.0      0      0            112053        S
# 888         0       3  female  28.0      1      2        W./C. 6607        S
# 889         1       1    male  26.0      0      0            111369        C
# 890         0       3    male  32.0      0      0            370376        Q
#
# [891 rows x 8 columns]

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("titanic_data.csv")
sns.countplot(x='Survived',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("titanic_data.csv")
sns.boxplot(x='Survived',y='Age',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("titanic_data.csv")
sns.violinplot(x="Survived",y="Age",data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("titanic_data.csv")
lived = df.loc[df["Survived"] == 1]
dead = df.loc[df["Survived"] == 0]

sns.kdeplot(lived["Age"],color='b',fill=True,label='lived')
sns.kdeplot(dead["Age"],color='g',fill=True,label='dead')

plt.show()

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("titanic_data.csv")
lived = df.loc[df["Survived"] == 1]
dead = df.loc[df["Survived"] == 0]

sns.kdeplot(lived["Pclass"],color='g',fill=True,label='lived')
sns.kdeplot(dead["Pclass"],color='r',fill=True,label='dead')
# Out:
# <Axes: xlabel='Pclass', ylabel='Density'>

# %%
'''
Perform following operations on StudentsPerformance.csv
1) Plot histogram for math score column of given dataframe
2) Draw barplot for gender and math score. Take x=gender,
y=math score; and data=df.
3) Draw barplot for gender and reading score.Take x=gender,
y=reading score, and data=df
4) Draw violin plot violinplot .Take x=&quot;gender&quot;, y=&quot;math score&quot; &amp;
data=df
'''

#-> 1)1) Plot histogram for math score column of given dataframe
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('StudentsPerformance.csv')
plt.title("Histogram")
plt.xlabel("maths score")
plt.ylabel("Freqency")
plt.hist(df["math score"],10)
plt.show()

# %%
#->2)Draw barplot for gender and math score. Take x=gender,y=math score; and data=df

import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('StudentsPerformance.csv')
df.loc[df['gender']=="male","gender"] = 0
df.loc[df['gender']=="female","gender"] = 1
sns.barplot(x='gender',y='math score',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
#3

import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('StudentsPerformance.csv')
sns.barplot(x='gender',y='reading score',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
#4
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('StudentsPerformance.csv')
sns.violinplot(x='gender',y='reading score',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>
